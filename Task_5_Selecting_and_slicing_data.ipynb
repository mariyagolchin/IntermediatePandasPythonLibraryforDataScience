# %% [markdown]
# <a href="https://colab.research.google.com/github/mariyagolchin/IntermediatePandasPythonLibraryforDataScience/blob/main/Task_5_Selecting_and_slicing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/VinitaSilaparasetty/Coursera-Intermediate-Pandas/master/What_does_aid_to_Africa_finance_1.csv ")
df.head()
# Out:
#        countryc  year  ...              dcnlnhthp              dcnlnothp
# 0  Burkina Faso  1970  ...  1.79769313486232e+308  1.79769313486232e+308
# 1  Burkina Faso  1970  ...  1.79769313486232e+308  1.79769313486232e+308
# 2  Burkina Faso  1971  ...  1.79769313486232e+308  1.79769313486232e+308
# 3  Burkina Faso  1972  ...  1.79769313486232e+308  1.79769313486232e+308
# 4  Burkina Faso  1973  ...                      0      -0.11642000079155
#
# [5 rows x 50 columns]

# %%
# selection
df1=df[['countryc','year']]
df1
# Out:
#          countryc  year
# 0    Burkina Faso  1970
# 1    Burkina Faso  1970
# 2    Burkina Faso  1971
# 3    Burkina Faso  1972
# 4    Burkina Faso  1973
# ..            ...   ...
# 296        Malawi  1976
# 297        Malawi  1977
# 298        Malawi  1978
# 299        Malawi  1979
# 300        Malawi  1980
#
# [301 rows x 2 columns]

# %%
df2= df[df.columns[1:7]].head()
df2
# Out:
#    year       agrgdp       popn      infmort schprim schsec
# 0  1970  35.44188862  5633000.0  141.3999939      13      1
# 1  1970  35.44188862  5633000.0  141.3999939      13      1
# 2  1971  36.16739069  5740700.0  139.1999969    13.6    1.2
# 3  1972  37.51058767  5848380.0          137    14.2    1.4
# 4  1973  34.83428571  5958700.0          135    14.8    1.6

# %% [markdown]
# # Slicing

# %%
df.loc[:3]
# Out:
#        countryc  year  ...              dcnlnhthp              dcnlnothp
# 0  Burkina Faso  1970  ...  1.79769313486232e+308  1.79769313486232e+308
# 1  Burkina Faso  1970  ...  1.79769313486232e+308  1.79769313486232e+308
# 2  Burkina Faso  1971  ...  1.79769313486232e+308  1.79769313486232e+308
# 3  Burkina Faso  1972  ...  1.79769313486232e+308  1.79769313486232e+308
#
# [4 rows x 50 columns]

# %%
df.iloc[:3]
# Out:
#        countryc  year  ...              dcnlnhthp              dcnlnothp
# 0  Burkina Faso  1970  ...  1.79769313486232e+308  1.79769313486232e+308
# 1  Burkina Faso  1970  ...  1.79769313486232e+308  1.79769313486232e+308
# 2  Burkina Faso  1971  ...  1.79769313486232e+308  1.79769313486232e+308
#
# [3 rows x 50 columns]

# %%
df3=df[df.columns[23:29]].head()
df3
# Out:
#               cnlnenp            cnlninp  ... cnlnhthp           cnlnothp
# 0                   0  0.320718288421631  ...        0  0.289336889982224
# 1                   0  0.320718288421631  ...        0  0.289336889982224
# 2                   0  0.317928194999695  ...        0  0.124712198972702
# 3                   0  0.185248598456383  ...        0  0.616943776607513
# 4  0.0578907988965511   2.71574592590332  ...        0  0.500525176525116
#
# [5 rows x 6 columns]
